# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

import time

from sklearn.preprocessing import LabelEncoder
from data_load_utils import load_image, load_data, create_data_frame

import PIL
from PIL import Image

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader, WeightedRandomSampler
from torchvision.datasets import ImageFolder
from torchvision import transforms

# %%
from torchvision.models import ResNet50_Weights

# %% [markdown]
# ## Loading & Preparing Data for ResNet50

# %%
training_dir = "./data/train"
testing_dir = "./data/test"

# %%
weights = ResNet50_Weights.IMAGENET1K_V2

# %%
transform = weights.transforms()

# %%
train_dataset = ImageFolder(root=training_dir, transform=transform)

# %%
labels = [label for _, label in train_dataset.samples]

# %%
counts = {}
for label in labels:
    try:
        counts[label] += 1
    except:
        counts[label] = 1

# %%
class_weights = [v for v in counts.values()]

# %%
class_weights
# Out:
# [3995, 436, 4097, 7215, 4965, 4830, 3171]

# %%
sample_weights = [0] *len(train_dataset)

# %%
for i, (data, label) in enumerate(train_dataset):
    class_weight = class_weights[label]
    sample_weights[i] = class_weight

# %%
sampler = WeightedRandomSampler(sample_weights, num_samples = len(sample_weights), replacement = True)

# %%
train_loader = DataLoader(train_dataset, batch_size = 10, sampler = sampler)

# %% [markdown]
# Inspecting Training Data Distribution

# %%
from collections import Counter

# %%
names = train_dataset.classes
counts = [class_counts[i] for i in range(len(names))]

plt.bar(names, counts)
plt.title("Training Data Distribution")
plt.xticks(rotation=45)
plt.savefig("./graphics/Training_Data_Distribution")
plt.show()

# %% [markdown]
# ## Loading & Training ResNet50

# %%
model = torchvision.models.resnet50(weights = weights, progress = True)

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
num_ftrs = model.fc.in_features

# %%
model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 1024),
    nn.ReLU(),
    nn.Dropout(0.4),

    nn.Linear(1024, 512),
    nn.ReLU(),
    nn.Dropout(0.3),

    nn.Linear(512, 7)
    )

# %%
model = model.to("cuda")

# %%
criterion = nn.CrossEntropyLoss().to("cuda")
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)

# %%
losses = []
scores = {}
epoch_count = 0

# %%
epochs = 10

start_time = time.time()

for epoch in range(epochs):
    model.train()
    corrects = 0
    wrongs = 0 
    running_loss = 0
    for b, (X_train, y_train) in enumerate(train_loader):
        X_train = X_train.to("cuda")
        y_train = y_train.to("cuda")
        batch = b+1
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)

        predicted = torch.argmax(y_pred, dim = 1)

        corrects += (predicted == y_train).sum().item()
        wrongs += (predicted != y_train).sum().item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if b%100 == 0:
            print(f"Epoch: {epoch}/{epochs} Batch: {batch} Current Loss: {running_loss/batch}")
    
    scores[epoch_count] = {
        "corrects": corrects,
        "wrongs": wrongs,
        "accuracy": corrects/(wrongs+corrects),
        "loss": running_loss/batch
    }
    epoch_count += 1
    print(f"Epoch: {epoch}. Current Accuracy: {corrects/(wrongs+corrects)}")
    losses.append(running_loss/batch)

end_time = time.time()
total_time = (end_time-start_time)/60
print(f"Training took {total_time} minutes")
# Out:
# Epoch: 0/10 Batch: 1 Current Loss: 1.4925458431243896
# Epoch: 0/10 Batch: 101 Current Loss: 1.3710620515417344
# Epoch: 0/10 Batch: 201 Current Loss: 1.3725087191928085
# Epoch: 0/10 Batch: 301 Current Loss: 1.3873432165760535
# Epoch: 0/10 Batch: 401 Current Loss: 1.3916227093658542
# Epoch: 0/10 Batch: 501 Current Loss: 1.3896208282954203
# Epoch: 0/10 Batch: 601 Current Loss: 1.3818681558436046
# Epoch: 0/10 Batch: 701 Current Loss: 1.375535445529622
# Epoch: 0/10 Batch: 801 Current Loss: 1.3775439198395136
# Epoch: 0/10 Batch: 901 Current Loss: 1.3723220167625758
# Epoch: 0/10 Batch: 1001 Current Loss: 1.367676555395841
# Epoch: 0/10 Batch: 1101 Current Loss: 1.3749296995426286
# Epoch: 0/10 Batch: 1201 Current Loss: 1.3725280294708169
# Epoch: 0/10 Batch: 1301 Current Loss: 1.3732512450328156
# Epoch: 0/10 Batch: 1401 Current Loss: 1.3697123396915678
# Epoch: 0/10 Batch: 1501 Current Loss: 1.368854462465074
# Epoch: 0/10 Batch: 1601 Current Loss: 1.3691211802969867
# Epoch: 0/10 Batch: 1701 Current Loss: 1.3669014601129983
# Epoch: 0/10 Batch: 1801 Current Loss: 1.3690433499549641
# Epoch: 0/10 Batch: 1901 Current Loss: 1.3673200817374038
# Epoch: 0/10 Batch: 2001 Current Loss: 1.3665199209486825
# Epoch: 0/10 Batch: 2101 Current Loss: 1.3665898940723207
# Epoch: 0/10 Batch: 2201 Current Loss: 1.3658132829865453
# Epoch: 0/10 Batch: 2301 Current Loss: 1.3675622115804547
# Epoch: 0/10 Batch: 2401 Current Loss: 1.3665821389176855
# Epoch: 0/10 Batch: 2501 Current Loss: 1.3657532958734613
# Epoch: 0/10 Batch: 2601 Current Loss: 1.3671799556240125
# Epoch: 0/10 Batch: 2701 Current Loss: 1.3666701710740534
# Epoch: 0/10 Batch: 2801 Current Loss: 1.366306333893412
# Epoch: 0. Current Accuracy: 0.4801281827998189
# Epoch: 1/10 Batch: 1 Current Loss: 1.3455127477645874
# Epoch: 1/10 Batch: 101 Current Loss: 1.3440904918283518
# Epoch: 1/10 Batch: 201 Current Loss: 1.3542628822041982
# Epoch: 1/10 Batch: 301 Current Loss: 1.351573368441623
# Epoch: 1/10 Batch: 401 Current Loss: 1.349992960171212
# Epoch: 1/10 Batch: 501 Current Loss: 1.3539890690953909
# Epoch: 1/10 Batch: 601 Current Loss: 1.3511889940887045
# Epoch: 1/10 Batch: 701 Current Loss: 1.3535595898451376
# Epoch: 1/10 Batch: 801 Current Loss: 1.3510192646813601
# Epoch: 1/10 Batch: 901 Current Loss: 1.356285563253536
# Epoch: 1/10 Batch: 1001 Current Loss: 1.3563938859578493
# Epoch: 1/10 Batch: 1101 Current Loss: 1.3558101089405645
# Epoch: 1/10 Batch: 1201 Current Loss: 1.3558935598469495
# Epoch: 1/10 Batch: 1301 Current Loss: 1.3589217274762593
# Epoch: 1/10 Batch: 1401 Current Loss: 1.3569390926081992
# Epoch: 1/10 Batch: 1501 Current Loss: 1.3553927182396757
# Epoch: 1/10 Batch: 1601 Current Loss: 1.3564877747782016
# Epoch: 1/10 Batch: 1701 Current Loss: 1.3594813435691584
# Epoch: 1/10 Batch: 1801 Current Loss: 1.359675452468926
# Epoch: 1/10 Batch: 1901 Current Loss: 1.3586722019313198
# Epoch: 1/10 Batch: 2001 Current Loss: 1.3586716768236413
# Epoch: 1/10 Batch: 2101 Current Loss: 1.356352854305537
# Epoch: 1/10 Batch: 2201 Current Loss: 1.3531485276431292
# Epoch: 1/10 Batch: 2301 Current Loss: 1.3523942157399493
# Epoch: 1/10 Batch: 2401 Current Loss: 1.353790645808391
# Epoch: 1/10 Batch: 2501 Current Loss: 1.3541782056627536
# Epoch: 1/10 Batch: 2601 Current Loss: 1.3553928619552145
# Epoch: 1/10 Batch: 2701 Current Loss: 1.3572055604426079
# Epoch: 1/10 Batch: 2801 Current Loss: 1.359490338403044
# Epoch: 1. Current Accuracy: 0.4854226897488592
# Epoch: 2/10 Batch: 1 Current Loss: 1.4731677770614624
# Epoch: 2/10 Batch: 101 Current Loss: 1.3369836518079927
# Epoch: 2/10 Batch: 201 Current Loss: 1.3518562165658865
# Epoch: 2/10 Batch: 301 Current Loss: 1.3582056402368008
# Epoch: 2/10 Batch: 401 Current Loss: 1.3508604264021515
# Epoch: 2/10 Batch: 501 Current Loss: 1.3534849628716885
# Epoch: 2/10 Batch: 601 Current Loss: 1.3505622555134498
# Epoch: 2/10 Batch: 701 Current Loss: 1.3624979954813414
# Epoch: 2/10 Batch: 801 Current Loss: 1.358960703071137
# Epoch: 2/10 Batch: 901 Current Loss: 1.359144208500044
# Epoch: 2/10 Batch: 1001 Current Loss: 1.3563424856155426
# Epoch: 2/10 Batch: 1101 Current Loss: 1.3553259880514603
# Epoch: 2/10 Batch: 1201 Current Loss: 1.3520827273544325
# Epoch: 2/10 Batch: 1301 Current Loss: 1.3546816879836163
# Epoch: 2/10 Batch: 1401 Current Loss: 1.3544929718052294
# Epoch: 2/10 Batch: 1501 Current Loss: 1.352289418750092
# Epoch: 2/10 Batch: 1601 Current Loss: 1.3545337860320674
# Epoch: 2/10 Batch: 1701 Current Loss: 1.356443547207352
# Epoch: 2/10 Batch: 1801 Current Loss: 1.3555957699139736
# Epoch: 2/10 Batch: 1901 Current Loss: 1.3543659755896418
# Epoch: 2/10 Batch: 2001 Current Loss: 1.3539017479399453
# Epoch: 2/10 Batch: 2101 Current Loss: 1.35424236851837
# Epoch: 2/10 Batch: 2201 Current Loss: 1.354650102599758
# Epoch: 2/10 Batch: 2301 Current Loss: 1.3550932478873638
# Epoch: 2/10 Batch: 2401 Current Loss: 1.3566610022963508
# Epoch: 2/10 Batch: 2501 Current Loss: 1.3557761291035269
# Epoch: 2/10 Batch: 2601 Current Loss: 1.3529471910627746
# Epoch: 2/10 Batch: 2701 Current Loss: 1.353772394615648
# Epoch: 2/10 Batch: 2801 Current Loss: 1.3542969351749428
# Epoch: 2. Current Accuracy: 0.4875126267024278
# Epoch: 3/10 Batch: 1 Current Loss: 1.4610704183578491
# Epoch: 3/10 Batch: 101 Current Loss: 1.356254526884249
# Epoch: 3/10 Batch: 201 Current Loss: 1.3399634841662735
# Epoch: 3/10 Batch: 301 Current Loss: 1.3569480341138238
# Epoch: 3/10 Batch: 401 Current Loss: 1.3596832912758996
# Epoch: 3/10 Batch: 501 Current Loss: 1.3600839498990072
# Epoch: 3/10 Batch: 601 Current Loss: 1.356045231347076
# Epoch: 3/10 Batch: 701 Current Loss: 1.3602449064928184
# Epoch: 3/10 Batch: 801 Current Loss: 1.3601632342951724
# Epoch: 3/10 Batch: 901 Current Loss: 1.357347195540099
# Epoch: 3/10 Batch: 1001 Current Loss: 1.3524474262833952
# Epoch: 3/10 Batch: 1101 Current Loss: 1.3467098861039497
# Epoch: 3/10 Batch: 1201 Current Loss: 1.348646501617368
# Epoch: 3/10 Batch: 1301 Current Loss: 1.3475248856236621
# Epoch: 3/10 Batch: 1401 Current Loss: 1.3477827281206527
# Epoch: 3/10 Batch: 1501 Current Loss: 1.349621794884559
# Epoch: 3/10 Batch: 1601 Current Loss: 1.3507228419603519
# Epoch: 3/10 Batch: 1701 Current Loss: 1.3494556526237904
# Epoch: 3/10 Batch: 1801 Current Loss: 1.349283573099271
# Epoch: 3/10 Batch: 1901 Current Loss: 1.3474813303403137
# Epoch: 3/10 Batch: 2001 Current Loss: 1.3482556536399026
# Epoch: 3/10 Batch: 2101 Current Loss: 1.3485939683998158
# Epoch: 3/10 Batch: 2201 Current Loss: 1.3477823836648535
# Epoch: 3/10 Batch: 2301 Current Loss: 1.3450960705250254
# Epoch: 3/10 Batch: 2401 Current Loss: 1.3440248399215755
# Epoch: 3/10 Batch: 2501 Current Loss: 1.3442793892460412
# Epoch: 3/10 Batch: 2601 Current Loss: 1.3463664194658507
# Epoch: 3/10 Batch: 2701 Current Loss: 1.348552567898808
# Epoch: 3/10 Batch: 2801 Current Loss: 1.3498161085713383
# Epoch: 3. Current Accuracy: 0.48866209202689054
# Epoch: 4/10 Batch: 1 Current Loss: 1.4511172771453857
# Epoch: 4/10 Batch: 101 Current Loss: 1.3186838638664473
# Epoch: 4/10 Batch: 201 Current Loss: 1.342486337939305
# Epoch: 4/10 Batch: 301 Current Loss: 1.335987574832384
# Epoch: 4/10 Batch: 401 Current Loss: 1.3372854104363117
# Epoch: 4/10 Batch: 501 Current Loss: 1.3431207763696622
# Epoch: 4/10 Batch: 601 Current Loss: 1.344575480296092
# Epoch: 4/10 Batch: 701 Current Loss: 1.3486183281461794
# Epoch: 4/10 Batch: 801 Current Loss: 1.3516827503988955
# Epoch: 4/10 Batch: 901 Current Loss: 1.3558410754743613
# Epoch: 4/10 Batch: 1001 Current Loss: 1.3600420792262395
# Epoch: 4/10 Batch: 1101 Current Loss: 1.361392884499154
# Epoch: 4/10 Batch: 1201 Current Loss: 1.3612265420595275
# Epoch: 4/10 Batch: 1301 Current Loss: 1.359948692598497
# Epoch: 4/10 Batch: 1401 Current Loss: 1.3590831175010432
# Epoch: 4/10 Batch: 1501 Current Loss: 1.3569534911385066
# Epoch: 4/10 Batch: 1601 Current Loss: 1.3523262021394167
# Epoch: 4/10 Batch: 1701 Current Loss: 1.3526201254476315
# Epoch: 4/10 Batch: 1801 Current Loss: 1.3516487834322526
# Epoch: 4/10 Batch: 1901 Current Loss: 1.351961127774832
# Epoch: 4/10 Batch: 2001 Current Loss: 1.3517007974610813
# Epoch: 4/10 Batch: 2101 Current Loss: 1.35219218953912
# Epoch: 4/10 Batch: 2201 Current Loss: 1.34806544796438
# Epoch: 4/10 Batch: 2301 Current Loss: 1.347141034651818
# Epoch: 4/10 Batch: 2401 Current Loss: 1.3460425480312728
# Epoch: 4/10 Batch: 2501 Current Loss: 1.3480017026368736
# Epoch: 4/10 Batch: 2601 Current Loss: 1.347236168391427
# Epoch: 4/10 Batch: 2701 Current Loss: 1.348014769080567
# Epoch: 4/10 Batch: 2801 Current Loss: 1.346846302006339
# Epoch: 4. Current Accuracy: 0.49141384234908914
# Epoch: 5/10 Batch: 1 Current Loss: 1.5773308277130127
# Epoch: 5/10 Batch: 101 Current Loss: 1.3390837093391041
# Epoch: 5/10 Batch: 201 Current Loss: 1.3703072646364052
# Epoch: 5/10 Batch: 301 Current Loss: 1.3454232205980243
# Epoch: 5/10 Batch: 401 Current Loss: 1.337480714939479
# Epoch: 5/10 Batch: 501 Current Loss: 1.3423883920896078
# Epoch: 5/10 Batch: 601 Current Loss: 1.3391377885210731
# Epoch: 5/10 Batch: 701 Current Loss: 1.3364985290165465
# Epoch: 5/10 Batch: 801 Current Loss: 1.3309879567888048
# Epoch: 5/10 Batch: 901 Current Loss: 1.336110173266683
# Epoch: 5/10 Batch: 1001 Current Loss: 1.33626339318869
# Epoch: 5/10 Batch: 1101 Current Loss: 1.3315838437314254
# Epoch: 5/10 Batch: 1201 Current Loss: 1.3298946859735334
# Epoch: 5/10 Batch: 1301 Current Loss: 1.331008848825113
# Epoch: 5/10 Batch: 1401 Current Loss: 1.331166854719874
# Epoch: 5/10 Batch: 1501 Current Loss: 1.333417404261849
# Epoch: 5/10 Batch: 1601 Current Loss: 1.331671453951896
# Epoch: 5/10 Batch: 1701 Current Loss: 1.3300996828541765
# Epoch: 5/10 Batch: 1801 Current Loss: 1.333069295965255
# Epoch: 5/10 Batch: 1901 Current Loss: 1.33465268870895
# Epoch: 5/10 Batch: 2001 Current Loss: 1.3339862744251767
# Epoch: 5/10 Batch: 2101 Current Loss: 1.3317502440582396
# Epoch: 5/10 Batch: 2201 Current Loss: 1.3337986175443086
# Epoch: 5/10 Batch: 2301 Current Loss: 1.3318145889036037
# Epoch: 5/10 Batch: 2401 Current Loss: 1.3329185942767412
# Epoch: 5/10 Batch: 2501 Current Loss: 1.3328865195502761
# Epoch: 5/10 Batch: 2601 Current Loss: 1.3331482124896932
# Epoch: 5/10 Batch: 2701 Current Loss: 1.33550338054842
# Epoch: 5/10 Batch: 2801 Current Loss: 1.3338503341766734
# Epoch: 5. Current Accuracy: 0.4933644501724198
# Epoch: 6/10 Batch: 1 Current Loss: 0.8979182243347168
# Epoch: 6/10 Batch: 101 Current Loss: 1.311897068330557
# Epoch: 6/10 Batch: 201 Current Loss: 1.3217975176982026
# Epoch: 6/10 Batch: 301 Current Loss: 1.3255212295094994
# Epoch: 6/10 Batch: 401 Current Loss: 1.3284697556436211
# Epoch: 6/10 Batch: 501 Current Loss: 1.3212659675442053
# Epoch: 6/10 Batch: 601 Current Loss: 1.325072578106466
# Epoch: 6/10 Batch: 701 Current Loss: 1.3268855133342334
# Epoch: 6/10 Batch: 801 Current Loss: 1.3281710258732724
# Epoch: 6/10 Batch: 901 Current Loss: 1.32779739573846
# Epoch: 6/10 Batch: 1001 Current Loss: 1.326325166654158
# Epoch: 6/10 Batch: 1101 Current Loss: 1.3237543721614806
# Epoch: 6/10 Batch: 1201 Current Loss: 1.3231245563687333
# Epoch: 6/10 Batch: 1301 Current Loss: 1.3225881632340128
# Epoch: 6/10 Batch: 1401 Current Loss: 1.3228516564209234
# Epoch: 6/10 Batch: 1501 Current Loss: 1.3258453581350633
# Epoch: 6/10 Batch: 1601 Current Loss: 1.3255167233802467
# Epoch: 6/10 Batch: 1701 Current Loss: 1.3282892174891765
# Epoch: 6/10 Batch: 1801 Current Loss: 1.3260872756885462
# Epoch: 6/10 Batch: 1901 Current Loss: 1.3238619603275437
# Epoch: 6/10 Batch: 2001 Current Loss: 1.326969137226326
# Epoch: 6/10 Batch: 2101 Current Loss: 1.3283714871642591
# Epoch: 6/10 Batch: 2201 Current Loss: 1.3303366215973211
# Epoch: 6/10 Batch: 2301 Current Loss: 1.3317872701339855
# Epoch: 6/10 Batch: 2401 Current Loss: 1.3325644066213618
# Epoch: 6/10 Batch: 2501 Current Loss: 1.3338327131381944
# Epoch: 6/10 Batch: 2601 Current Loss: 1.332881961612232
# Epoch: 6/10 Batch: 2701 Current Loss: 1.3325825256137926
# Epoch: 6/10 Batch: 2801 Current Loss: 1.3331461332177146
# Epoch: 6. Current Accuracy: 0.49433975408408515
# Epoch: 7/10 Batch: 1 Current Loss: 1.3189752101898193
# Epoch: 7/10 Batch: 101 Current Loss: 1.2788665129406618
# Epoch: 7/10 Batch: 201 Current Loss: 1.2905599961233376
# Epoch: 7/10 Batch: 301 Current Loss: 1.322888082642096
# Epoch: 7/10 Batch: 401 Current Loss: 1.325933014662783
# Epoch: 7/10 Batch: 501 Current Loss: 1.3340475986341755
# Epoch: 7/10 Batch: 601 Current Loss: 1.338964491537129
# Epoch: 7/10 Batch: 701 Current Loss: 1.33612798147977
# Epoch: 7/10 Batch: 801 Current Loss: 1.3382815230502916
# Epoch: 7/10 Batch: 901 Current Loss: 1.3338145574639562
# Epoch: 7/10 Batch: 1001 Current Loss: 1.3352836832538113
# Epoch: 7/10 Batch: 1101 Current Loss: 1.334471658400034
# Epoch: 7/10 Batch: 1201 Current Loss: 1.3322860648689618
# Epoch: 7/10 Batch: 1301 Current Loss: 1.3331268258868136
# Epoch: 7/10 Batch: 1401 Current Loss: 1.3325465436836041
# Epoch: 7/10 Batch: 1501 Current Loss: 1.3304105164764881
# Epoch: 7/10 Batch: 1601 Current Loss: 1.3322661920386059
# Epoch: 7/10 Batch: 1701 Current Loss: 1.3313149844878285
# Epoch: 7/10 Batch: 1801 Current Loss: 1.3318275861578608
# Epoch: 7/10 Batch: 1901 Current Loss: 1.33020302034064
# Epoch: 7/10 Batch: 2001 Current Loss: 1.3305938412909624
# Epoch: 7/10 Batch: 2101 Current Loss: 1.3328295106521282
# Epoch: 7/10 Batch: 2201 Current Loss: 1.3306363376228987
# Epoch: 7/10 Batch: 2301 Current Loss: 1.3310544753349227
# Epoch: 7/10 Batch: 2401 Current Loss: 1.331488375276985
# Epoch: 7/10 Batch: 2501 Current Loss: 1.3312695171179079
# Epoch: 7/10 Batch: 2601 Current Loss: 1.3304886181897175
# Epoch: 7/10 Batch: 2701 Current Loss: 1.3284955110451946
# Epoch: 7/10 Batch: 2801 Current Loss: 1.3288878434068685
# Epoch: 7. Current Accuracy: 0.4931206241945035
# Epoch: 8/10 Batch: 1 Current Loss: 1.189618468284607
# Epoch: 8/10 Batch: 101 Current Loss: 1.336517079631881
# Epoch: 8/10 Batch: 201 Current Loss: 1.3210306796268445
# Epoch: 8/10 Batch: 301 Current Loss: 1.3177634675637433
# Epoch: 8/10 Batch: 401 Current Loss: 1.3277805282588018
# Epoch: 8/10 Batch: 501 Current Loss: 1.3267584472835183
# Epoch: 8/10 Batch: 601 Current Loss: 1.3247704714189552
# Epoch: 8/10 Batch: 701 Current Loss: 1.3236595899844477
# Epoch: 8/10 Batch: 801 Current Loss: 1.3207866237702293
# Epoch: 8/10 Batch: 901 Current Loss: 1.320384596614012
# Epoch: 8/10 Batch: 1001 Current Loss: 1.3218092271736213
# Epoch: 8/10 Batch: 1101 Current Loss: 1.3180259384424657
# Epoch: 8/10 Batch: 1201 Current Loss: 1.321052638517629
# Epoch: 8/10 Batch: 1301 Current Loss: 1.317914361636699
# Epoch: 8/10 Batch: 1401 Current Loss: 1.3176352290661313
# Epoch: 8/10 Batch: 1501 Current Loss: 1.32348602644846
# Epoch: 8/10 Batch: 1601 Current Loss: 1.327853203341039
# Epoch: 8/10 Batch: 1701 Current Loss: 1.3270348350066847
# Epoch: 8/10 Batch: 1801 Current Loss: 1.329010436496491
# Epoch: 8/10 Batch: 1901 Current Loss: 1.3284066717979595
# Epoch: 8/10 Batch: 2001 Current Loss: 1.3295713414971915
# Epoch: 8/10 Batch: 2101 Current Loss: 1.3286804815861568
# Epoch: 8/10 Batch: 2201 Current Loss: 1.3307805843431264
# Epoch: 8/10 Batch: 2301 Current Loss: 1.3303258329927792
# Epoch: 8/10 Batch: 2401 Current Loss: 1.331200941335852
# Epoch: 8/10 Batch: 2501 Current Loss: 1.3311868404112355
# Epoch: 8/10 Batch: 2601 Current Loss: 1.3313479802096087
# Epoch: 8/10 Batch: 2701 Current Loss: 1.332099872335422
# Epoch: 8/10 Batch: 2801 Current Loss: 1.3329869742820792
# Epoch: 8. Current Accuracy: 0.49214532028283814
# Epoch: 9/10 Batch: 1 Current Loss: 1.43332839012146
# Epoch: 9/10 Batch: 101 Current Loss: 1.3607468475209605
# Epoch: 9/10 Batch: 201 Current Loss: 1.3552931461168165
# Epoch: 9/10 Batch: 301 Current Loss: 1.3400741702694434
# Epoch: 9/10 Batch: 401 Current Loss: 1.3288667644943084
# Epoch: 9/10 Batch: 501 Current Loss: 1.3252379483805445
# Epoch: 9/10 Batch: 601 Current Loss: 1.331561706625483
# Epoch: 9/10 Batch: 701 Current Loss: 1.3345453150772335
# Epoch: 9/10 Batch: 801 Current Loss: 1.3301714698175962
# Epoch: 9/10 Batch: 901 Current Loss: 1.3303340951954485
# Epoch: 9/10 Batch: 1001 Current Loss: 1.3331779197498517
# Epoch: 9/10 Batch: 1101 Current Loss: 1.3300311448463626
# Epoch: 9/10 Batch: 1201 Current Loss: 1.3314540839810654
# Epoch: 9/10 Batch: 1301 Current Loss: 1.335446979704497
# Epoch: 9/10 Batch: 1401 Current Loss: 1.331712062872792
# Epoch: 9/10 Batch: 1501 Current Loss: 1.3316850095173265
# Epoch: 9/10 Batch: 1601 Current Loss: 1.3316902682082792
# Epoch: 9/10 Batch: 1701 Current Loss: 1.329122895741729
# Epoch: 9/10 Batch: 1801 Current Loss: 1.3277049596146833
# Epoch: 9/10 Batch: 1901 Current Loss: 1.3305237647547714
# Epoch: 9/10 Batch: 2001 Current Loss: 1.3301166953413799
# Epoch: 9/10 Batch: 2101 Current Loss: 1.330542734751867
# Epoch: 9/10 Batch: 2201 Current Loss: 1.3294327384718219
# Epoch: 9/10 Batch: 2301 Current Loss: 1.3305171694718252
# Epoch: 9/10 Batch: 2401 Current Loss: 1.33032415244342
# Epoch: 9/10 Batch: 2501 Current Loss: 1.331469997412107
# Epoch: 9/10 Batch: 2601 Current Loss: 1.3315587179425221
# Epoch: 9/10 Batch: 2701 Current Loss: 1.3312527844306496
# Epoch: 9/10 Batch: 2801 Current Loss: 1.330710485146668
# Epoch: 9. Current Accuracy: 0.4997387578808039
# Training took 14.867132274309794 minutes

# %%
#Saving Model
torch.save(model, "./models/resnet50_complex_fc_weighed_classes.pth")

# %%
#Saving Model Params in order to make continued training possible
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict()
}, "./models/resnet50_complex_fc_weighed_classes_checkpoint.pth")

# %%
#Saving Scores Dict in order to keep track of model improvements in case of continued training
with open("./models/resnet_50_complex_fc_weighed_classes_scores.pkl", "wb") as f:
    pickle.dump(scores, f)

# %%
accuracies = []
for v in scores.values():
    accuracies.append(v["accuracy"])

# %%
accuracies
# Out:
# [0.4101849594203908,
#  0.43495071232017835,
#  0.44877912849629037,
#  0.45828834163502735,
#  0.4629906997805566,
#  0.46438399108293565,
#  0.46222438956424816,
#  0.4767146191089902,
#  0.4729527325925668,
#  0.48385523703368283,
#  0.4801281827998189,
#  0.4854226897488592,
#  0.4875126267024278,
#  0.48866209202689054,
#  0.49141384234908914,
#  0.4933644501724198,
#  0.49433975408408515,
#  0.4931206241945035,
#  0.49214532028283814,
#  0.4997387578808039]

# %%
plt.plot(range(len(losses)), losses, label = "Loss")
plt.plot(range(len(accuracies)), accuracies, label = "Accuracy")
for i, v in enumerate(losses):
    if i%2 == 0:
        plt.text(i -0.2, v+0.05, f"{v:.3}")

for i, v in enumerate(accuracies):
    if i%2 == 0:
        plt.text(i-0.2, v+0.05, f"{v:.3}")
plt.ylim(0,1.8)
plt.legend()
plt.title("ResNet50 Weighed Classes Loss and Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.savefig("./graphics/ResNet50_complex_weighted_classes_Loss_Accuracy")
plt.show()

# %% [markdown]
# ## Evaluating on testing Data

# %%
testing_data = ImageFolder(root = testing_dir, transform = transform)

# %%
testing_data.samples[0]
# Out:
# ('./data/test\\angry\\PrivateTest_10131363.jpg', 0)

# %%
testing_loader = DataLoader(testing_data, batch_size = 10, shuffle = False)

# %%
predictions = []

# %%
model.eval()
with torch.no_grad():
    for X_test, y_test in testing_loader:
        X_test = X_test.to("cuda")
        y_test = y_test.to("cuda")
        y_pred = model(X_test)
        preds = torch.argmax(y_pred, dim = 1)
        predictions.extend(preds)

# %%
actual = [label for _, label in testing_data]

# %%
len(actual)
# Out:
# 7178

# %%
preds = [p.item() for p in predictions]

# %%
len(predictions)
# Out:
# 7178

# %%
corrects = 0
for i, v in enumerate(preds):
    if v == actual[i]:
        corrects += 1

# %%
corrects/len(actual)
# Out:
# 0.40749512398996934
