# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

import time

from sklearn.preprocessing import LabelEncoder
from data_load_utils import load_image, load_data, create_data_frame

import PIL
from PIL import Image

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader, WeightedRandomSampler
from torchvision.datasets import ImageFolder
from torchvision import transforms

# %%
from torchvision.models import ResNet50_Weights

# %% [markdown]
# ## Loading & Preparing Data for ResNet50

# %%
training_dir = "./data/train"
testing_dir = "./data/test"

# %%
weights = ResNet50_Weights.IMAGENET1K_V2

# %%
transform = weights.transforms()

# %%
train_dataset = ImageFolder(root=training_dir, transform=transform)

# %%
labels = [label for _, label in train_dataset.samples]

# %%
counts = {}
for label in labels:
    try:
        counts[label] += 1
    except:
        counts[label] = 1

# %%
class_weights = [v for v in counts.values()]

# %%
class_weights
# Out:
# [3995, 436, 4097, 7215, 4965, 4830, 3171]

# %%
sample_weights = [0] *len(train_dataset)

# %%
for i, (data, label) in enumerate(train_dataset):
    class_weight = class_weights[label]
    sample_weights[i] = class_weight

# %%
sampler = WeightedRandomSampler(sample_weights, num_samples = len(sample_weights), replacement = True)

# %%
train_loader = DataLoader(train_dataset, batch_size = 10, sampler = sampler)

# %% [markdown]
# Inspecting Training Data Distribution

# %%
from collections import Counter

# %%
names = train_dataset.classes
counts = [class_counts[i] for i in range(len(names))]

plt.bar(names, counts)
plt.title("Training Data Distribution")
plt.xticks(rotation=45)
plt.savefig("./graphics/Training_Data_Distribution")
plt.show()

# %% [markdown]
# ## Loading & Training ResNet50

# %%
model = torchvision.models.resnet50(weights = weights, progress = True)

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
for param in model.layer4.parameters():
    param.requires_grad = True

# %%
num_ftrs = model.fc.in_features

# %%
model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 1024),
    nn.ReLU(),
    nn.Dropout(0.4),

    nn.Linear(1024, 512),
    nn.ReLU(),
    nn.Dropout(0.3),

    nn.Linear(512, 7)
    )

# %%
model = model.to("cuda")

# %%
criterion = nn.CrossEntropyLoss().to("cuda")
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)

# %%
losses = []
scores = {}
epoch_count = 0

# %%
epochs = 20

start_time = time.time()

for epoch in range(epochs):
    model.train()
    corrects = 0
    wrongs = 0 
    running_loss = 0
    for b, (X_train, y_train) in enumerate(train_loader):
        X_train = X_train.to("cuda")
        y_train = y_train.to("cuda")
        batch = b+1
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)

        predicted = torch.argmax(y_pred, dim = 1)

        corrects += (predicted == y_train).sum().item()
        wrongs += (predicted != y_train).sum().item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if b%100 == 0:
            print(f"Epoch: {epoch}/{epochs} Batch: {batch} Current Loss: {running_loss/batch}")
    
    scores[epoch_count] = {
        "corrects": corrects,
        "wrongs": wrongs,
        "accuracy": corrects/(wrongs+corrects),
        "loss": running_loss/batch
    }
    epoch_count += 1
    print(f"Epoch: {epoch}. Current Accuracy: {corrects/(wrongs+corrects)}")
    losses.append(running_loss/batch)

end_time = time.time()
total_time = (end_time-start_time)/60
print(f"Training took {total_time} minutes")
# Out:
# Epoch: 0/20 Batch: 1 Current Loss: 1.7999303340911865
# Epoch: 0/20 Batch: 101 Current Loss: 1.4986775428941934
# Epoch: 0/20 Batch: 201 Current Loss: 1.5238274534543355
# Epoch: 0/20 Batch: 301 Current Loss: 1.5118168598393664
# Epoch: 0/20 Batch: 401 Current Loss: 1.49642139242177
# Epoch: 0/20 Batch: 501 Current Loss: 1.4919700024132718
# Epoch: 0/20 Batch: 601 Current Loss: 1.4811931764226587
# Epoch: 0/20 Batch: 701 Current Loss: 1.4809681743425922
# Epoch: 0/20 Batch: 801 Current Loss: 1.4819097711650024
# Epoch: 0/20 Batch: 901 Current Loss: 1.4818160689366644
# Epoch: 0/20 Batch: 1001 Current Loss: 1.4789412643287803
# Epoch: 0/20 Batch: 1101 Current Loss: 1.4787076534627244
# Epoch: 0/20 Batch: 1201 Current Loss: 1.4809416006943468
# Epoch: 0/20 Batch: 1301 Current Loss: 1.4792970072572549
# Epoch: 0/20 Batch: 1401 Current Loss: 1.4766763217273906
# Epoch: 0/20 Batch: 1501 Current Loss: 1.4743640697216844
# Epoch: 0/20 Batch: 1601 Current Loss: 1.4756784329259491
# Epoch: 0/20 Batch: 1701 Current Loss: 1.476331584808197
# Epoch: 0/20 Batch: 1801 Current Loss: 1.4770696605330769
# Epoch: 0/20 Batch: 1901 Current Loss: 1.4761596781087511
# Epoch: 0/20 Batch: 2001 Current Loss: 1.4778181750258466
# Epoch: 0/20 Batch: 2101 Current Loss: 1.4771652823967458
# Epoch: 0/20 Batch: 2201 Current Loss: 1.4784710940205472
# Epoch: 0/20 Batch: 2301 Current Loss: 1.4772088381322972
# Epoch: 0/20 Batch: 2401 Current Loss: 1.476792282931063
# Epoch: 0/20 Batch: 2501 Current Loss: 1.4767354974170914
# Epoch: 0/20 Batch: 2601 Current Loss: 1.4765472469399499
# Epoch: 0/20 Batch: 2701 Current Loss: 1.4750983736462966
# Epoch: 0/20 Batch: 2801 Current Loss: 1.4745776592004047
# Epoch: 0. Current Accuracy: 0.431049496673517
# Epoch: 1/20 Batch: 1 Current Loss: 1.2579187154769897
# Epoch: 1/20 Batch: 101 Current Loss: 1.4334476419014506
# Epoch: 1/20 Batch: 201 Current Loss: 1.418279718107252
# Epoch: 1/20 Batch: 301 Current Loss: 1.4241027826090589
# Epoch: 1/20 Batch: 401 Current Loss: 1.426442874191408
# Epoch: 1/20 Batch: 501 Current Loss: 1.423677355705383
# Epoch: 1/20 Batch: 601 Current Loss: 1.4284448078190428
# Epoch: 1/20 Batch: 701 Current Loss: 1.4289761449232932
# Epoch: 1/20 Batch: 801 Current Loss: 1.4306442550803242
# Epoch: 1/20 Batch: 901 Current Loss: 1.4338898393475388
# Epoch: 1/20 Batch: 1001 Current Loss: 1.4377191260858968
# Epoch: 1/20 Batch: 1101 Current Loss: 1.4350450604639737
# Epoch: 1/20 Batch: 1201 Current Loss: 1.4327905306609643
# Epoch: 1/20 Batch: 1301 Current Loss: 1.4310209259539728
# Epoch: 1/20 Batch: 1401 Current Loss: 1.4332143520560119
# Epoch: 1/20 Batch: 1501 Current Loss: 1.4340566180293994
# Epoch: 1/20 Batch: 1601 Current Loss: 1.4324354569216506
# Epoch: 1/20 Batch: 1701 Current Loss: 1.4324356742216375
# Epoch: 1/20 Batch: 1801 Current Loss: 1.43258708841201
# Epoch: 1/20 Batch: 1901 Current Loss: 1.4342140673274182
# Epoch: 1/20 Batch: 2001 Current Loss: 1.4348966744111693
# Epoch: 1/20 Batch: 2101 Current Loss: 1.433763006396205
# Epoch: 1/20 Batch: 2201 Current Loss: 1.435097402439828
# Epoch: 1/20 Batch: 2301 Current Loss: 1.4369959747568517
# Epoch: 1/20 Batch: 2401 Current Loss: 1.4382518328313578
# Epoch: 1/20 Batch: 2501 Current Loss: 1.4349727890149253
# Epoch: 1/20 Batch: 2601 Current Loss: 1.4347835803481075
# Epoch: 1/20 Batch: 2701 Current Loss: 1.4337629404433434
# Epoch: 1/20 Batch: 2801 Current Loss: 1.4328409908116608
# Epoch: 1. Current Accuracy: 0.45275000870807064
# Epoch: 2/20 Batch: 1 Current Loss: 1.4431886672973633
# Epoch: 2/20 Batch: 101 Current Loss: 1.4639415770474047
# Epoch: 2/20 Batch: 201 Current Loss: 1.4394883430419276
# Epoch: 2/20 Batch: 301 Current Loss: 1.4408760264862415
# Epoch: 2/20 Batch: 401 Current Loss: 1.433481877581437
# Epoch: 2/20 Batch: 501 Current Loss: 1.4322796051135795
# Epoch: 2/20 Batch: 601 Current Loss: 1.4306654455062753
# Epoch: 2/20 Batch: 701 Current Loss: 1.4287101354306502
# Epoch: 2/20 Batch: 801 Current Loss: 1.4269113990846793
# Epoch: 2/20 Batch: 901 Current Loss: 1.4245915363287422
# Epoch: 2/20 Batch: 1001 Current Loss: 1.425980032145322
# Epoch: 2/20 Batch: 1101 Current Loss: 1.4216155450415546
# Epoch: 2/20 Batch: 1201 Current Loss: 1.4283582932446819
# Epoch: 2/20 Batch: 1301 Current Loss: 1.430760549362763
# Epoch: 2/20 Batch: 1401 Current Loss: 1.4304324988379469
# Epoch: 2/20 Batch: 1501 Current Loss: 1.430753009784706
# Epoch: 2/20 Batch: 1601 Current Loss: 1.427589735822481
# Epoch: 2/20 Batch: 1701 Current Loss: 1.4256139789378903
# Epoch: 2/20 Batch: 1801 Current Loss: 1.4246176087412816
# Epoch: 2/20 Batch: 1901 Current Loss: 1.4216643204066954
# Epoch: 2/20 Batch: 2001 Current Loss: 1.4190989442910629
# Epoch: 2/20 Batch: 2101 Current Loss: 1.419583926082849
# Epoch: 2/20 Batch: 2201 Current Loss: 1.4189952392840266
# Epoch: 2/20 Batch: 2301 Current Loss: 1.4203256153635542
# Epoch: 2/20 Batch: 2401 Current Loss: 1.42035897507463
# Epoch: 2/20 Batch: 2501 Current Loss: 1.4198226684429607
# Epoch: 2/20 Batch: 2601 Current Loss: 1.4212583781938652
# Epoch: 2/20 Batch: 2701 Current Loss: 1.4213235776365267
# Epoch: 2/20 Batch: 2801 Current Loss: 1.420790646702679
# Epoch: 2. Current Accuracy: 0.45574558500818557
# Epoch: 3/20 Batch: 1 Current Loss: 1.207061529159546
# Epoch: 3/20 Batch: 101 Current Loss: 1.4290249684069416
# Epoch: 3/20 Batch: 201 Current Loss: 1.4140598204598498
# Epoch: 3/20 Batch: 301 Current Loss: 1.4308534842788976
# Epoch: 19/20 Batch: 2001 Current Loss: 1.3217990446364742
# Epoch: 19/20 Batch: 2101 Current Loss: 1.3245714980043268
# Epoch: 19/20 Batch: 2201 Current Loss: 1.3239381381838173
# Epoch: 19/20 Batch: 2301 Current Loss: 1.325932738186224
# Epoch: 19/20 Batch: 2401 Current Loss: 1.3270055002244698
# Epoch: 19/20 Batch: 2501 Current Loss: 1.3269102550515743
# Epoch: 19/20 Batch: 2601 Current Loss: 1.3272834910607623
# Epoch: 19/20 Batch: 2701 Current Loss: 1.326765433279332
# Epoch: 19/20 Batch: 2801 Current Loss: 1.3273322552240392
# Epoch: 19. Current Accuracy: 0.4947229091922394
# Training took 31.450067245960234 minutes

# %%
#Saving Model
torch.save(model, "./models/resnet50_complex_last_layer_weighed_classes.pth")

# %%
#Saving Model Params in order to make continued training possible
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict()
}, "./models/resnet50_complex_last_layer_weighed_classes_checkpoint.pth")

# %%
#Saving Scores Dict in order to keep track of model improvements in case of continued training
with open("./models/resnet_50_complex_last_layer_weighed_classes_scores.pkl", "wb") as f:
    pickle.dump(scores, f)

# %%
accuracies = []
for v in scores.values():
    accuracies.append(v["accuracy"])

# %%
accuracies
# Out:
# [0.3987948030234421,
#  0.431049496673517,
#  0.45275000870807064,
#  0.45574558500818557,
#  0.4571737085931241,
#  0.467553728795848,
#  0.4704448082482845,
#  0.4774460970427392,
#  0.4713504475948309,
#  0.4785955623672019,
#  0.48221811975338746,
#  0.4798146922567836,
#  0.4822529520359469,
#  0.48291476540457695,
#  0.4834372496429691,
#  0.49047337071998326,
#  0.4936431084328956,
#  0.49165766832700547,
#  0.4931206241945035,
#  0.4956633808213452,
#  0.4947229091922394]

# %%
plt.plot(range(len(losses)), losses, label = "Loss")
plt.plot(range(len(accuracies)), accuracies, label = "Accuracy")
for i, v in enumerate(losses):
    if i%2 == 0:
        plt.text(i -0.2, v+0.05, f"{v:.3}")

for i, v in enumerate(accuracies):
    if i%2 == 0:
        plt.text(i-0.2, v+0.05, f"{v:.3}")
plt.ylim(0,1.8)
plt.legend()
plt.title("ResNet50 Weighed Classes Fine-tuned last Layer Loss and Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.savefig("./graphics/ResNet50_complex_last_layer_weighted_classes_Loss_Accuracy")
plt.show()

# %% [markdown]
# ## Evaluating on testing Data

# %%
testing_data = ImageFolder(root = testing_dir, transform = transform)

# %%
testing_data.samples[0]
# Out:
# ('./data/test\\angry\\PrivateTest_10131363.jpg', 0)

# %%
testing_loader = DataLoader(testing_data, batch_size = 10, shuffle = False)

# %%
predictions = []

# %%
model.eval()
with torch.no_grad():
    for X_test, y_test in testing_loader:
        X_test = X_test.to("cuda")
        y_test = y_test.to("cuda")
        y_pred = model(X_test)
        preds = torch.argmax(y_pred, dim = 1)
        predictions.extend(preds)

# %%
actual = [label for _, label in testing_data]

# %%
len(actual)
# Out:
# 7178

# %%
preds = [p.item() for p in predictions]

# %%
len(predictions)
# Out:
# 7178

# %%
corrects = 0
for i, v in enumerate(preds):
    if v == actual[i]:
        corrects += 1

# %%
corrects/len(actual)
# Out:
# 0.3967679019225411
