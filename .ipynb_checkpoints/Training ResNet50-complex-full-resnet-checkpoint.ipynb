# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

import time

from sklearn.preprocessing import LabelEncoder
from data_load_utils import load_image, load_data, create_data_frame

import PIL
from PIL import Image

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torchvision.datasets import ImageFolder
from torchvision import transforms

# %%
from torchvision.models import ResNet50_Weights

# %% [markdown]
# ## Loading & Preparing Data for ResNet50

# %%
training_dir = "./data/train"
testing_dir = "./data/test"

# %%
weights = ResNet50_Weights.IMAGENET1K_V2

# %%
transform = weights.transforms()

# %%
train_dataset = ImageFolder(root=training_dir, transform=transform)

# %%
train_loader = DataLoader(train_dataset, batch_size = 10, shuffle = True)

# %% [markdown]
# ## Loading & Training ResNet50

# %%
model = torchvision.models.resnet50(weights = weights, progress = True)

# %%
num_ftrs = model.fc.in_features

# %%
model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 1024),
    nn.ReLU(),
    nn.Dropout(0.4),

    nn.Linear(1024, 512),
    nn.ReLU(),
    nn.Dropout(0.3),

    nn.Linear(512, 7)
    )

# %%
model = model.to("cuda")

# %%
criterion = nn.CrossEntropyLoss().to("cuda")
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)

# %%
losses = []
scores = {}
epoch_count = 0

# %%
epochs = 20

start_time = time.time()

for epoch in range(epochs):
    model.train()
    corrects = 0
    wrongs = 0 
    running_loss = 0
    for b, (X_train, y_train) in enumerate(train_loader):
        X_train = X_train.to("cuda")
        y_train = y_train.to("cuda")
        batch = b+1
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)

        predicted = torch.argmax(y_pred, dim = 1)

        corrects += (predicted == y_train).sum().item()
        wrongs += (predicted != y_train).sum().item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if b%100 == 0:
            print(f"Epoch: {epoch}/{epochs} Batch: {batch} Current Loss: {running_loss/batch}")
    
    scores[epoch_count] = {
        "corrects": corrects,
        "wrongs": wrongs,
        "accuracy": corrects/(wrongs+corrects),
        "loss": running_loss/batch
    }
    epoch_count += 1
    print(f"Epoch: {epoch}. Current Accuracy: {corrects/(wrongs+corrects)}")
    losses.append(running_loss/batch)

end_time = time.time()
total_time = (end_time-start_time)/60
print(f"Training took {total_time} minutes")
# Out:
# Epoch: 0/20 Batch: 1 Current Loss: 1.9444847106933594
# Epoch: 0/20 Batch: 101 Current Loss: 1.847110689276516
# Epoch: 0/20 Batch: 201 Current Loss: 1.822960196442865
# Epoch: 0/20 Batch: 301 Current Loss: 1.7980858642001485
# Epoch: 0/20 Batch: 401 Current Loss: 1.7811788338378183
# Epoch: 0/20 Batch: 501 Current Loss: 1.7754460777827128
# Epoch: 0/20 Batch: 601 Current Loss: 1.7653803123213885
# Epoch: 0/20 Batch: 701 Current Loss: 1.761455184382821
# Epoch: 0/20 Batch: 801 Current Loss: 1.7546524255909723
# Epoch: 0/20 Batch: 901 Current Loss: 1.7498243506026188
# Epoch: 0/20 Batch: 1001 Current Loss: 1.7449670073750254
# Epoch: 0/20 Batch: 1101 Current Loss: 1.7424458858644172
# Epoch: 0/20 Batch: 1201 Current Loss: 1.738301722036611
# Epoch: 0/20 Batch: 1301 Current Loss: 1.7325883453209339
# Epoch: 0/20 Batch: 1401 Current Loss: 1.726760910375896
# Epoch: 0/20 Batch: 1501 Current Loss: 1.723486384814934
# Epoch: 0/20 Batch: 1601 Current Loss: 1.720879950648468
# Epoch: 0/20 Batch: 1701 Current Loss: 1.7169947684476965
# Epoch: 0/20 Batch: 1801 Current Loss: 1.7138313913530672
# Epoch: 0/20 Batch: 1901 Current Loss: 1.7108126002070403
# Epoch: 0/20 Batch: 2001 Current Loss: 1.709199032921722
# Epoch: 0/20 Batch: 2101 Current Loss: 1.7071959797057126
# Epoch: 0/20 Batch: 2201 Current Loss: 1.704145195970531
# Epoch: 0/20 Batch: 2301 Current Loss: 1.7025393691077433
# Epoch: 0/20 Batch: 2401 Current Loss: 1.6996417881200234
# Epoch: 0/20 Batch: 2501 Current Loss: 1.6963349707076092
# Epoch: 0/20 Batch: 2601 Current Loss: 1.6936570771241912
# Epoch: 0/20 Batch: 2701 Current Loss: 1.6916909721417588
# Epoch: 0/20 Batch: 2801 Current Loss: 1.6904433061718218
# Epoch: 0. Current Accuracy: 0.3258211710613397
# Epoch: 1/20 Batch: 1 Current Loss: 1.666280746459961
# Epoch: 1/20 Batch: 101 Current Loss: 1.6063145328276227
# Epoch: 1/20 Batch: 201 Current Loss: 1.6205187413229871
# Epoch: 1/20 Batch: 301 Current Loss: 1.610426177614155
# Epoch: 1/20 Batch: 401 Current Loss: 1.6078005859679414
# Epoch: 1/20 Batch: 501 Current Loss: 1.603328771933824
# Epoch: 1/20 Batch: 601 Current Loss: 1.604855555861246
# Epoch: 1/20 Batch: 701 Current Loss: 1.6051029420953333
# Epoch: 1/20 Batch: 801 Current Loss: 1.6078985194290771
# Epoch: 1/20 Batch: 901 Current Loss: 1.6060764998627555
# Epoch: 1/20 Batch: 1001 Current Loss: 1.6121361375926853
# Epoch: 1/20 Batch: 1101 Current Loss: 1.6118728006893024
# Epoch: 1/20 Batch: 1201 Current Loss: 1.6118280577917679
# Epoch: 1/20 Batch: 1301 Current Loss: 1.6151560720895273
# Epoch: 1/20 Batch: 1401 Current Loss: 1.6135031021466688
# Epoch: 1/20 Batch: 1501 Current Loss: 1.611245576260012
# Epoch: 1/20 Batch: 1601 Current Loss: 1.6109889217796063
# Epoch: 1/20 Batch: 1701 Current Loss: 1.6100737867742199
# Epoch: 1/20 Batch: 1801 Current Loss: 1.6092219998080621
# Epoch: 1/20 Batch: 1901 Current Loss: 1.60848147056405
# Epoch: 1/20 Batch: 2001 Current Loss: 1.6080352891271916
# Epoch: 1/20 Batch: 2101 Current Loss: 1.6075676978627367
# Epoch: 1/20 Batch: 2201 Current Loss: 1.6074652854608764
# Epoch: 1/20 Batch: 2301 Current Loss: 1.607462019673745
# Epoch: 1/20 Batch: 2401 Current Loss: 1.6096154499530593
# Epoch: 1/20 Batch: 2501 Current Loss: 1.6118343291116781
# Epoch: 1/20 Batch: 2601 Current Loss: 1.6108579144758337
# Epoch: 1/20 Batch: 2701 Current Loss: 1.6118730427114578
# Epoch: 1/20 Batch: 2801 Current Loss: 1.6117848481335244
# Epoch: 1. Current Accuracy: 0.3711728029537776
# Epoch: 2/20 Batch: 1 Current Loss: 1.5838758945465088
# Epoch: 2/20 Batch: 101 Current Loss: 1.573841369978272
# Epoch: 2/20 Batch: 201 Current Loss: 1.5836845719399144
# Epoch: 2/20 Batch: 301 Current Loss: 1.588337700232319
# Epoch: 2/20 Batch: 401 Current Loss: 1.5795352527328264
# Epoch: 2/20 Batch: 501 Current Loss: 1.5716650643034609
# Epoch: 2/20 Batch: 601 Current Loss: 1.5774427539298617
# Epoch: 2/20 Batch: 701 Current Loss: 1.5739094925334893
# Epoch: 2/20 Batch: 801 Current Loss: 1.580749353665984
# Epoch: 2/20 Batch: 901 Current Loss: 1.5789534278238786
# Epoch: 2/20 Batch: 1001 Current Loss: 1.5788548311868034
# Epoch: 2/20 Batch: 1101 Current Loss: 1.579315616259458
# Epoch: 2/20 Batch: 1201 Current Loss: 1.5806642472992134
# Epoch: 2/20 Batch: 1301 Current Loss: 1.5823270185098202
# Epoch: 2/20 Batch: 1401 Current Loss: 1.5865023229736503
# Epoch: 2/20 Batch: 1501 Current Loss: 1.5844228057604008
# Epoch: 2/20 Batch: 1601 Current Loss: 1.5832123387463013
# Epoch: 2/20 Batch: 1701 Current Loss: 1.5847180727507912
# Epoch: 2/20 Batch: 1801 Current Loss: 1.5847131016848817
# Epoch: 2/20 Batch: 1901 Current Loss: 1.5853851737316378
# Epoch: 2/20 Batch: 2001 Current Loss: 1.5846144944235778
# Epoch: 2/20 Batch: 2101 Current Loss: 1.5844330074729265
# Epoch: 2/20 Batch: 2201 Current Loss: 1.5853594655017862
# Epoch: 2/20 Batch: 2301 Current Loss: 1.5846214183047251
# Epoch: 2/20 Batch: 2401 Current Loss: 1.584190204534765
# Epoch: 2/20 Batch: 2501 Current Loss: 1.5840171719255185
# Epoch: 2/20 Batch: 2601 Current Loss: 1.5831076086186209
# Epoch: 2/20 Batch: 2701 Current Loss: 1.5836563360819063
# Epoch: 2/20 Batch: 2801 Current Loss: 1.5833005702780725
# Epoch: 2. Current Accuracy: 0.38110000348322826
# Epoch: 3/20 Batch: 1 Current Loss: 1.6550943851470947
# Epoch: 3/20 Batch: 101 Current Loss: 1.5143680761356164
# Epoch: 3/20 Batch: 201 Current Loss: 1.5576689548753386
# Epoch: 3/20 Batch: 301 Current Loss: 1.560810379015647
# Epoch: 3/20 Batch: 401 Current Loss: 1.5588929989094151
# Epoch: 3/20 Batch: 501 Current Loss: 1.5601062346361354
# Epoch: 3/20 Batch: 601 Current Loss: 1.5665125880582558
# Epoch: 3/20 Batch: 701 Current Loss: 1.5682893850323818
# Epoch: 3/20 Batch: 801 Current Loss: 1.5689951693371738
# Epoch: 3/20 Batch: 901 Current Loss: 1.5709366068062056
# Epoch: 3/20 Batch: 1001 Current Loss: 1.5665769197128632
# Epoch: 3/20 Batch: 1101 Current Loss: 1.5656524118134154
# Epoch: 3/20 Batch: 1201 Current Loss: 1.5658366606694079
# Epoch: 3/20 Batch: 1301 Current Loss: 1.567439505451006
# Epoch: 19/20 Batch: 2001 Current Loss: 1.464887375208451
# Epoch: 19/20 Batch: 2101 Current Loss: 1.4658739276014017
# Epoch: 19/20 Batch: 2201 Current Loss: 1.4661261268985752
# Epoch: 19/20 Batch: 2301 Current Loss: 1.4661638232636898
# Epoch: 19/20 Batch: 2401 Current Loss: 1.4636144008501426
# Epoch: 19/20 Batch: 2501 Current Loss: 1.463095893315533
# Epoch: 19/20 Batch: 2601 Current Loss: 1.463455091641986
# Epoch: 19/20 Batch: 2701 Current Loss: 1.4625394009122668
# Epoch: 19/20 Batch: 2801 Current Loss: 1.464937442309173
# Epoch: 19. Current Accuracy: 0.4390609216621965
# Training took 54.58150850534439 minutes

# %%
#Saving Model
torch.save(model, "./models/resnet50_complex_full.pth")

# %%
#Saving Model Params in order to make continued training possible
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict()
}, "./models/resnet50_complex_full_checkpoint.pth")

# %%
#Saving Scores Dict in order to keep track of model improvements in case of continued training
with open("./models/resnet_50_complex_full_scores.pkl", "wb") as f:
    pickle.dump(scores, f)

# %%
accuracies = []
for v in scores.values():
    accuracies.append(v["accuracy"])

# %%
accuracies
# Out:
# [0.3258211710613397,
#  0.3711728029537776,
#  0.38110000348322826,
#  0.39074854575220314,
#  0.4006060817165349,
#  0.4042286391027204,
#  0.40624891149117004,
#  0.4155142986519907,
#  0.40994113344247446,
#  0.4148873175659201,
#  0.42443136298721656,
#  0.424535859834895,
#  0.42505834407328713,
#  0.42805392037340206,
#  0.42850674004667527,
#  0.4322337942805392,
#  0.43348775645268034,
#  0.4329652722142882,
#  0.4393744122052318,
#  0.4390609216621965]

# %%
plt.plot(range(len(losses)), losses, label = "Loss")
plt.plot(range(len(accuracies)), accuracies, label = "Accuracy")
for i, v in enumerate(losses):
    if i%2 == 0:
        plt.text(i -0.2, v+0.05, f"{v:.3}")

for i, v in enumerate(accuracies):
    if i%2 == 0:
        plt.text(i-0.2, v+0.05, f"{v:.3}")
plt.ylim(0,1.8)
plt.legend()
plt.title("ResNet50 fully Fine-tuned Loss and Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.savefig("./graphics/ResNet50_complex_full_Loss_Accuracy")
plt.show()

# %% [markdown]
# ## Evaluating on testing Data

# %%
testing_data = ImageFolder(root = testing_dir, transform = transform)

# %%
testing_data.samples[0]
# Out:
# ('./data/test\\angry\\PrivateTest_10131363.jpg', 0)

# %%
testing_loader = DataLoader(testing_data, batch_size = 10, shuffle = False)

# %%
predictions = []

# %%
model.eval()
with torch.no_grad():
    for X_test, y_test in testing_loader:
        X_test = X_test.to("cuda")
        y_test = y_test.to("cuda")
        y_pred = model(X_test)
        preds = torch.argmax(y_pred, dim = 1)
        predictions.extend(preds)

# %%
actual = [label for _, label in testing_data]

# %%
len(actual)
# Out:
# 7178

# %%
preds = [p.item() for p in predictions]

# %%
len(predictions)
# Out:
# 7178

# %%
corrects = 0
for i, v in enumerate(preds):
    if v == actual[i]:
        corrects += 1

# %%
corrects/len(actual)
# Out:
# 0.42407355809417663
