# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

import time

from sklearn.preprocessing import LabelEncoder
from data_load_utils import load_image, load_data, create_data_frame

import PIL
from PIL import Image

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader, WeightedRandomSampler
from torchvision.datasets import ImageFolder
from torchvision import transforms

# %%
from torchvision.models import ResNet50_Weights

# %% [markdown]
# ## Loading & Preparing Data for ResNet50

# %%
training_dir = "./data/train"
testing_dir = "./data/test"

# %%
weights = ResNet50_Weights.IMAGENET1K_V2

# %%
transform = weights.transforms()

# %%
train_dataset = ImageFolder(root=training_dir, transform=transform)

# %%
labels = [label for _, label in train_dataset.samples]

# %%
counts = {}
for label in labels:
    try:
        counts[label] += 1
    except:
        counts[label] = 1

# %%
class_weights = [v for v in counts.values()]

# %%
class_weights
# Out:
# [3995, 436, 4097, 7215, 4965, 4830, 3171]

# %%
sample_weights = [0] *len(train_dataset)

# %%
for i, (data, label) in enumerate(train_dataset):
    class_weight = class_weights[label]
    sample_weights[i] = class_weight

# %%
sampler = WeightedRandomSampler(sample_weights, num_samples = len(sample_weights), replacement = True)

# %%
train_loader = DataLoader(train_dataset, batch_size = 10, sampler = sampler)

# %% [markdown]
# Inspecting Training Data Distribution

# %%
from collections import Counter

# %%
names = train_dataset.classes
counts = [class_counts[i] for i in range(len(names))]

plt.bar(names, counts)
plt.title("Training Data Distribution")
plt.xticks(rotation=45)
plt.savefig("./graphics/Training_Data_Distribution")
plt.show()

# %% [markdown]
# ## Loading & Training ResNet50

# %%
model = torchvision.models.resnet50(weights = weights, progress = True)

# %%
num_ftrs = model.fc.in_features

# %%
model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 1024),
    nn.ReLU(),
    nn.Dropout(0.4),

    nn.Linear(1024, 512),
    nn.ReLU(),
    nn.Dropout(0.3),

    nn.Linear(512, 7)
    )

# %%
model = model.to("cuda")

# %%
criterion = nn.CrossEntropyLoss().to("cuda")
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)

# %%
losses = []
scores = {}
epoch_count = 0

# %%
epochs = 20

start_time = time.time()

for epoch in range(epochs):
    model.train()
    corrects = 0
    wrongs = 0 
    running_loss = 0
    for b, (X_train, y_train) in enumerate(train_loader):
        X_train = X_train.to("cuda")
        y_train = y_train.to("cuda")
        batch = b+1
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)

        predicted = torch.argmax(y_pred, dim = 1)

        corrects += (predicted == y_train).sum().item()
        wrongs += (predicted != y_train).sum().item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if b%100 == 0:
            print(f"Epoch: {epoch}/{epochs} Batch: {batch} Current Loss: {running_loss/batch}")
    
    scores[epoch_count] = {
        "corrects": corrects,
        "wrongs": wrongs,
        "accuracy": corrects/(wrongs+corrects),
        "loss": running_loss/batch
    }
    epoch_count += 1
    print(f"Epoch: {epoch}. Current Accuracy: {corrects/(wrongs+corrects)}")
    losses.append(running_loss/batch)

end_time = time.time()
total_time = (end_time-start_time)/60
print(f"Training took {total_time} minutes")
# Out:
# Epoch: 0/20 Batch: 1 Current Loss: 1.264383316040039
# Epoch: 0/20 Batch: 101 Current Loss: 1.551762318847203
# Epoch: 0/20 Batch: 201 Current Loss: 1.5222744766752518
# Epoch: 0/20 Batch: 301 Current Loss: 1.5185830840636725
# Epoch: 1/20 Batch: 1901 Current Loss: 1.443654388894789
# Epoch: 1/20 Batch: 2001 Current Loss: 1.4428147743309456
# Epoch: 1/20 Batch: 2101 Current Loss: 1.4429972415195085
# Epoch: 1/20 Batch: 2201 Current Loss: 1.441497015118978
# Epoch: 1/20 Batch: 2301 Current Loss: 1.440767948444073
# Epoch: 1/20 Batch: 2401 Current Loss: 1.441083784676353
# Epoch: 1/20 Batch: 2501 Current Loss: 1.440957415561493
# Epoch: 1/20 Batch: 2601 Current Loss: 1.4400051341795637
# Epoch: 1/20 Batch: 2701 Current Loss: 1.4407709514993245
# Epoch: 1/20 Batch: 2801 Current Loss: 1.4402012634771035
# Epoch: 1. Current Accuracy: 0.44738583719391134
# Epoch: 2/20 Batch: 1 Current Loss: 1.3100134134292603
# Epoch: 2/20 Batch: 101 Current Loss: 1.4563207673554373
# Epoch: 2/20 Batch: 201 Current Loss: 1.4419621238067968
# Epoch: 2/20 Batch: 301 Current Loss: 1.4569451179219244
# Epoch: 2/20 Batch: 401 Current Loss: 1.4618045885366693
# Epoch: 2/20 Batch: 501 Current Loss: 1.4579459786890985
# Epoch: 2/20 Batch: 601 Current Loss: 1.4567033716922195
# Epoch: 2/20 Batch: 701 Current Loss: 1.4542979110834773
# Epoch: 2/20 Batch: 801 Current Loss: 1.4471957505716664
# Epoch: 2/20 Batch: 901 Current Loss: 1.4427563499795741
# Epoch: 2/20 Batch: 1001 Current Loss: 1.4447896709213486
# Epoch: 2/20 Batch: 1101 Current Loss: 1.4456512762891716
# Epoch: 2/20 Batch: 1201 Current Loss: 1.4441014108411676
# Epoch: 2/20 Batch: 1301 Current Loss: 1.4368124968908458
# Epoch: 2/20 Batch: 1401 Current Loss: 1.43314677008895
# Epoch: 2/20 Batch: 1501 Current Loss: 1.431808864053768
# Epoch: 2/20 Batch: 1601 Current Loss: 1.4311527711834333
# Epoch: 2/20 Batch: 1701 Current Loss: 1.4290383690809376
# Epoch: 2/20 Batch: 1801 Current Loss: 1.428069266526319
# Epoch: 2/20 Batch: 1901 Current Loss: 1.425253078129842
# Epoch: 2/20 Batch: 2001 Current Loss: 1.4240294394047484
# Epoch: 2/20 Batch: 2101 Current Loss: 1.4229994183889405
# Epoch: 2/20 Batch: 2201 Current Loss: 1.4220386173496566
# Epoch: 2/20 Batch: 2301 Current Loss: 1.4224584553356743
# Epoch: 2/20 Batch: 2401 Current Loss: 1.424233822065907
# Epoch: 2/20 Batch: 2501 Current Loss: 1.4240382766304185
# Epoch: 2/20 Batch: 2601 Current Loss: 1.4235400377168697
# Epoch: 2/20 Batch: 2701 Current Loss: 1.4247077871189873
# Epoch: 2/20 Batch: 2801 Current Loss: 1.4257191571113426
# Epoch: 2. Current Accuracy: 0.4550489393569961
# Epoch: 3/20 Batch: 1 Current Loss: 1.383851408958435
# Epoch: 3/20 Batch: 101 Current Loss: 1.3858111022722603
# Epoch: 3/20 Batch: 201 Current Loss: 1.375870643860072
# Epoch: 3/20 Batch: 301 Current Loss: 1.3792268142747721
# Epoch: 19/20 Batch: 2001 Current Loss: 1.3225377765314272
# Epoch: 19/20 Batch: 2101 Current Loss: 1.3221787988203357
# Epoch: 19/20 Batch: 2201 Current Loss: 1.3231242583698166
# Epoch: 19/20 Batch: 2301 Current Loss: 1.3225364621076208
# Epoch: 19/20 Batch: 2401 Current Loss: 1.321053533914535
# Epoch: 19/20 Batch: 2501 Current Loss: 1.3205195606493654
# Epoch: 19/20 Batch: 2601 Current Loss: 1.322139236707955
# Epoch: 19/20 Batch: 2701 Current Loss: 1.3219874580451092
# Epoch: 19/20 Batch: 2801 Current Loss: 1.3219548918782962
# Epoch: 19. Current Accuracy: 0.501132049183183
# Training took 52.60102000633876 minutes

# %%
#Saving Model
torch.save(model, "./models/resnet50_complex_full_weighed_classes.pth")

# %%
#Saving Model Params in order to make continued training possible
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict()
}, "./models/resnet50_complex_full_weighed_classes_checkpoint.pth")

# %%
#Saving Scores Dict in order to keep track of model improvements in case of continued training
with open("./models/resnet_50_complex_full_weighed_classes_scores.pkl", "wb") as f:
    pickle.dump(scores, f)

# %%
accuracies = []
for v in scores.values():
    accuracies.append(v["accuracy"])

# %%
accuracies
# Out:
# [0.4023476958445087,
#  0.4309101675432791,
#  0.44738583719391134,
#  0.4550489393569961,
#  0.4696436657494166,
#  0.4713852798773904,
#  0.4688773555331081,
#  0.4673795673830506,
#  0.4720819255285799,
#  0.4771326064997039,
#  0.4789090529102372,
#  0.48531819290118083,
#  0.49005538332926957,
#  0.48604967083492984,
#  0.48409906301159916,
#  0.4891149117001637,
#  0.49461841234456094,
#  0.49169250060956493,
#  0.49827580201330596,
#  0.4971611689714027,
#  0.501132049183183]

# %%
plt.plot(range(len(losses)), losses, label = "Loss")
plt.plot(range(len(accuracies)), accuracies, label = "Accuracy")
for i, v in enumerate(losses):
    if i%2 == 0:
        plt.text(i -0.2, v+0.05, f"{v:.3}")

for i, v in enumerate(accuracies):
    if i%2 == 0:
        plt.text(i-0.2, v+0.05, f"{v:.3}")
plt.ylim(0,1.8)
plt.legend()
plt.title("ResNet50 Weighed Classes Fine-tuned full ResNet Loss and Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.savefig("./graphics/ResNet50_complex_full_weighted_classes_Loss_Accuracy")
plt.show()

# %% [markdown]
# ## Evaluating on testing Data

# %%
testing_data = ImageFolder(root = testing_dir, transform = transform)

# %%
testing_data.samples[0]
# Out:
# ('./data/test\\angry\\PrivateTest_10131363.jpg', 0)

# %%
testing_loader = DataLoader(testing_data, batch_size = 10, shuffle = False)

# %%
predictions = []

# %%
model.eval()
with torch.no_grad():
    for X_test, y_test in testing_loader:
        X_test = X_test.to("cuda")
        y_test = y_test.to("cuda")
        y_pred = model(X_test)
        preds = torch.argmax(y_pred, dim = 1)
        predictions.extend(preds)

# %%
actual = [label for _, label in testing_data]

# %%
len(actual)
# Out:
# 7178

# %%
preds = [p.item() for p in predictions]

# %%
len(predictions)
# Out:
# 7178

# %%
corrects = 0
for i, v in enumerate(preds):
    if v == actual[i]:
        corrects += 1

# %%
corrects/len(actual)
# Out:
# 0.4158539983282251
